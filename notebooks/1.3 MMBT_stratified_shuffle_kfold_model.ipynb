# %% [markdown]
# ## MMBTの学習にStratifiedShuffleSplitでそれぞれの学習モデルの結果の平均値を学習結果として提出
#
# baselineとの違いは、以下の点である。
#
# - StratifiedShuffleSplit でfoldごとに学習されたモデルを用いて予測したテストデータに対する予測結果の平均値を結果として提出
#
# 上記の実装により、hold-outでは用いることができなかったデータを用いたモデルとなる。

# %%
import os
import random
from pathlib import Path
import sys
import json
from glob import glob

import numpy as np
import pandas as pd
from sklearn.metrics import log_loss, accuracy_score
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.special import softmax
from transformers import (
    AutoTokenizer, Trainer, TrainingArguments,
)
from torchvision.models import ResNet152_Weights

sys.path.append('../')
from src.data.prepare import load_base_df
from src.models.MMBT.dataset import (BokeTextImageDataset, collate_fn)
from src.models.MMBT.mmbt import load_model
from src.models.utils import fix_seed, plot_confusion_matrix

# %%
SEED_SHUFFLE = 42
SEED_TRAIN = 0

# %% [markdown]
# ## データ読み込み

# %%
train_df, test_df, submission_df = load_base_df('../dataset/csv/', '../dataset/imgs/')

# %%
print(f'train_df.shape: {train_df.shape}')
display(train_df.head())

print(f'test_df.shape: {test_df.shape}')
display(test_df.head())
# Out:
# train_df.shape: (24962, 5)
#           id odai_photo_file_name  \
# 0  ge5kssftl       9fkys1gb2r.jpg
# 1  r7sm6tvkj       c6ag0m1lak.jpg
# 2  yp5aze0bh       whtn6gb9ww.jpg
# 3  ujaixzo56       6yk5cwmrsy.jpg
# 4  7vkeveptl       0i9gsa2jsm.jpg
#
#                                             text  is_laugh  \
# 0             君しょっちゅうソレ自慢するけど、ツムジ２個ってそんなに嬉しいのかい？         0
# 1                            これでバレない？授業中寝てもバレない？         0
# 2  「あなたも感じる？」\n『ああ…、感じてる…』\n「後ろに幽霊いるよね…」\n『女のな…』         0
# 3                 大塚愛聞いてたらお腹減った…さく、らんぼと牛タン食べたい…          0
# 4                                    熊だと思ったら嫁だった         0
#
#                                img_path
# 0  ../dataset/imgs/train/9fkys1gb2r.jpg
# 1  ../dataset/imgs/train/c6ag0m1lak.jpg
# 2  ../dataset/imgs/train/whtn6gb9ww.jpg
# 3  ../dataset/imgs/train/6yk5cwmrsy.jpg
# 4  ../dataset/imgs/train/0i9gsa2jsm.jpg
# test_df.shape: (6000, 5)
#           id odai_photo_file_name  \
# 0  rfdjcfsqq       nc1kez326b.jpg
# 1  tsgqmfpef       49xt2fmjw0.jpg
# 2  owjcthkz2       9dtscjmyfh.jpg
# 3  rvgaocjyy       osa3n56tiv.jpg
# 4  uxtwu5i69       yb1yqs4pvb.jpg
#
#                                                 text  \
# 0                          僕のママ、キャラ弁のゆでたまごに８時間かかったんだ
# 1                                          かわいいが作れた！
# 2                                           来世の志茂田景樹
# 3                       ちょ、あの、オカン、これ水風呂やねんけど、なんの冗談??
# 4  「今日は皆さんにザリガニと消防車の違いを知ってもらいたいと思います」『どっちも同じだろ。両方...
#
#                               img_path  is_laugh
# 0  ../dataset/imgs/test/nc1kez326b.jpg         0
# 1  ../dataset/imgs/test/49xt2fmjw0.jpg         0
# 2  ../dataset/imgs/test/9dtscjmyfh.jpg         0
# 3  ../dataset/imgs/test/osa3n56tiv.jpg         0
# 4  ../dataset/imgs/test/yb1yqs4pvb.jpg         0

# %% [markdown]
# ## データ準備, 学習

# %%
BATCH_SIZE = 8
EPOCHS = 3
GRADIENT_ACCUMULATION_STEPS = 20
SAVE_STEPS = 25


def create_trainer(
            model,
            model_dst,
            train_ds,
            valid_ds,
            train_batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
            save_steps=SAVE_STEPS
        ):
    trainer_args = TrainingArguments(
        output_dir=str(model_dst),
        overwrite_output_dir=True,
        do_train=True,
        do_eval=True,
        num_train_epochs=epochs,
        evaluation_strategy="steps",
        eval_steps=save_steps,
        save_strategy="steps",
        save_steps=save_steps,
        logging_steps=save_steps,
        per_device_train_batch_size=train_batch_size,
        per_device_eval_batch_size=12,
        save_total_limit=1,
        fp16=True,
        remove_unused_columns=False,
        gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
        load_best_model_at_end=True,
        logging_dir='./logs',
        report_to="none"
    )

    trainer = Trainer(
        model=model,
        args=trainer_args,
        tokenizer=tokenizer,
        train_dataset=train_ds,
        eval_dataset=valid_ds,
        data_collator=collate_fn,
    )
    return trainer

# %%
MAX_SEQENCE_LEN = 48
N_SPLIT = 5

# 結果保存用ディレクトリ準備
EXPERIMENT_NAME = f'{N_SPLIT}fold_stratified_shuffle_mmbt'
MODEL_DIR = Path('../model/') / EXPERIMENT_NAME
MODEL_DIR.mkdir(exist_ok=True, parents=True)
PLOT_DIR = Path('../plots') / EXPERIMENT_NAME
PLOT_DIR.mkdir(exist_ok=True, parents=True)
RESULT_DIR = Path('../results/') / EXPERIMENT_NAME
RESULT_DIR.mkdir(exist_ok=True, parents=True)

# %%
# seed固定
fix_seed(SEED_TRAIN)

# tokenizerとtest_ds準備
tokenizer = AutoTokenizer.from_pretrained("cl-tohoku/bert-base-japanese-whole-word-masking")
test_ds = BokeTextImageDataset(test_df, tokenizer, MAX_SEQENCE_LEN, image_transform=ResNet152_Weights.IMAGENET1K_V2)

# k-fold用インスタンス生成
sss = StratifiedShuffleSplit(n_splits=N_SPLIT, test_size=0.2, random_state=SEED_SHUFFLE)
for i, (train_idx, valid_idx) in enumerate(sss.split(train_df, train_df['is_laugh'])):
    k = i + 1
    # 学習 => MODEL_DIR配下に fold_{k}という名前で結果を保存
    model = load_model()
    model_dst = MODEL_DIR / f'fold_{k}'
    train_ds = BokeTextImageDataset(
        train_df.iloc[train_idx],
        tokenizer,
        MAX_SEQENCE_LEN,
        ResNet152_Weights.IMAGENET1K_V2
    )
    valid_ds = BokeTextImageDataset(
        train_df.iloc[valid_idx],
        tokenizer,
        MAX_SEQENCE_LEN,
        ResNet152_Weights.IMAGENET1K_V2
    )
    trainer = create_trainer(model, model_dst, train_ds, valid_ds)
    trainer.train()

    # 予測
    val_preds = trainer.predict(valid_ds).predictions

    # 評価(混同行列) => PLOT_DIR配下に fold_i_conf_matrix.pngという名前で結果を保存
    plot_confusion_matrix(y_true=valid_ds.df['is_laugh'].values, y_pred=val_preds, dst=str(PLOT_DIR / f'fold_{k}_conf_matrix.png'))

    # 評価(log_lossとaccuracy) => RESULT_DIR配下にfold_i_log.jsonという名前で結果を保存(このjsonにlog_loss, accuracy, 学習に使用したtrain_idx, valdi_idxを保存しておく)
    loss = log_loss(valid_ds.df["is_laugh"].values, softmax(val_preds, axis=-1))
    acc = accuracy_score(valid_ds.df['is_laugh'].values, np.argmax(val_preds, axis=-1))
    logs = {
        'log_loss': float(loss),
        'acc': float(acc),
        'train_idx': train_idx.tolist(),
        'valid_idx': valid_idx.tolist()
    }
    with open(str(RESULT_DIR / f'fold_{k}_log.json'), 'w') as f:
        json.dump(logs, f)

    # csv保存 => RESULT_DIR配下にfold_i_submission.csvという名前で結果を保存
    y_pred = trainer.predict(test_ds).predictions
    submission_df['is_laugh'] = softmax(y_pred, axis=1)[:, 1]
    submission_df["is_laugh"] = submission_df["is_laugh"].astype(float)
    output = str(RESULT_DIR / f'fold_{k}_submission.csv')
    submission_df.to_csv(output, index=False)
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/110 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/252k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/424M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading: "https://download.pytorch.org/models/resnet152-f82ba261.pth" to /root/.cache/torch/hub/checkpoints/resnet152-f82ba261.pth
#   0%|          | 0.00/230M [00:00<?, ?B/s]
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 19969
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 160
#   Gradient Accumulation steps = 20
#   Total optimization steps = 372
#     <div>
#
#       <progress value='372' max='372' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [372/372 31:01, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.690600</td>
#       <td>0.660162</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.663200</td>
#       <td>0.657856</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.658000</td>
#       <td>0.671017</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.652200</td>
#       <td>0.647973</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.676500</td>
#       <td>0.646846</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.630200</td>
#       <td>0.646744</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.620100</td>
#       <td>0.657836</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.607500</td>
#       <td>0.669254</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.621900</td>
#       <td>0.651430</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.625200</td>
#       <td>0.657130</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.534900</td>
#       <td>0.710127</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.536500</td>
#       <td>0.691447</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.532700</td>
#       <td>0.710779</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.510200</td>
#       <td>0.704156</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-25
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-25/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-50
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-50/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-50/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-25] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-75
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-75/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-75/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-100
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-100/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-50] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-75] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-125
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-125/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-125/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-150
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-150/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-150/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-125] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-175
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-175/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-175/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-200/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-175] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-225
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-225/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-225/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-250
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-250/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-250/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-225] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-275
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-275/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-275/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-300
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-275] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-325
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-325/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-325/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_1/checkpoint-350
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_1/checkpoint-350/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_1/checkpoint-350/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_1/checkpoint-325] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../model/5fold_mmbt/fold_1/checkpoint-150 (score: 0.6467435359954834).
# ***** Running Prediction *****
#   Num examples = 4993
#   Batch size = 12
# ***** Running Prediction *****
#   Num examples = 6000
#   Batch size = 12
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/cabd9bbd81093f4c494a02e34eb57e405b7564db216404108c8e8caf10ede4fa.464b54997e35e3cc3223ba6d7f0abdaeb7be5b7648f275f57d839ee0f95611fb
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.
# PyTorch: setting up devices
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 19969
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 160
#   Gradient Accumulation steps = 20
#   Total optimization steps = 372
#     <div>
#
#       <progress value='372' max='372' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [372/372 31:54, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.698600</td>
#       <td>0.676624</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.665300</td>
#       <td>0.670639</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.673700</td>
#       <td>0.671534</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.678600</td>
#       <td>0.662487</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.695800</td>
#       <td>0.677276</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.659100</td>
#       <td>0.656844</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.655000</td>
#       <td>0.660385</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.647500</td>
#       <td>0.652006</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.651500</td>
#       <td>0.667309</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.672100</td>
#       <td>0.657870</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.632800</td>
#       <td>0.652438</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.626500</td>
#       <td>0.653205</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.624200</td>
#       <td>0.653048</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.613500</td>
#       <td>0.658459</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-25
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-25/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-50
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-50/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-50/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-25] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-75
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-75/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-75/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-100
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-100/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-50] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-75] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-125
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-125/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-125/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-150
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-150/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-150/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-100] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-125] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-175
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-175/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-175/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-200/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-150] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-175] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-225
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-225/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-225/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-250
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-250/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-250/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-225] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-275
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-275/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-275/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-300
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-275] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-325
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-325/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-325/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_2/checkpoint-350
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_2/checkpoint-350/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_2/checkpoint-350/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_2/checkpoint-325] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../model/5fold_mmbt/fold_2/checkpoint-200 (score: 0.6520055532455444).
# ***** Running Prediction *****
#   Num examples = 4993
#   Batch size = 12
# ***** Running Prediction *****
#   Num examples = 6000
#   Batch size = 12
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/cabd9bbd81093f4c494a02e34eb57e405b7564db216404108c8e8caf10ede4fa.464b54997e35e3cc3223ba6d7f0abdaeb7be5b7648f275f57d839ee0f95611fb
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.
# PyTorch: setting up devices
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 19969
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 160
#   Gradient Accumulation steps = 20
#   Total optimization steps = 372
#     <div>
#
#       <progress value='372' max='372' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [372/372 31:02, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.683800</td>
#       <td>0.666564</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.669100</td>
#       <td>0.653364</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.665700</td>
#       <td>0.666565</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.654000</td>
#       <td>0.646478</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.678900</td>
#       <td>0.680588</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.636600</td>
#       <td>0.647834</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.626000</td>
#       <td>0.640323</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.630900</td>
#       <td>0.659704</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.629800</td>
#       <td>0.661636</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.636100</td>
#       <td>0.646052</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.567700</td>
#       <td>0.665449</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.544700</td>
#       <td>0.681364</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.552100</td>
#       <td>0.683873</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.541700</td>
#       <td>0.689702</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-25
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-25/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-50
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-50/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-50/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-25] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-75
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-75/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-75/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-100
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-100/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-50] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-75] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-125
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-125/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-125/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-150
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-150/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-150/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-125] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-175
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-175/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-175/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-100] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-200/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-225
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-225/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-225/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-250
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-250/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-250/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-225] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-275
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-275/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-275/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-300
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-275] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-325
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-325/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-325/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_3/checkpoint-350
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_3/checkpoint-350/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_3/checkpoint-350/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_3/checkpoint-325] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../model/5fold_mmbt/fold_3/checkpoint-175 (score: 0.6403229236602783).
# ***** Running Prediction *****
#   Num examples = 4993
#   Batch size = 12
# ***** Running Prediction *****
#   Num examples = 6000
#   Batch size = 12
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/cabd9bbd81093f4c494a02e34eb57e405b7564db216404108c8e8caf10ede4fa.464b54997e35e3cc3223ba6d7f0abdaeb7be5b7648f275f57d839ee0f95611fb
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.
# PyTorch: setting up devices
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 19969
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 160
#   Gradient Accumulation steps = 20
#   Total optimization steps = 372
#     <div>
#
#       <progress value='372' max='372' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [372/372 31:57, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.678300</td>
#       <td>0.687448</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.672500</td>
#       <td>0.665218</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.659800</td>
#       <td>0.656923</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.657500</td>
#       <td>0.657383</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.671200</td>
#       <td>0.651030</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.631200</td>
#       <td>0.648417</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.618900</td>
#       <td>0.663535</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.613700</td>
#       <td>0.662878</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.622600</td>
#       <td>0.656862</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.626800</td>
#       <td>0.653450</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.534300</td>
#       <td>0.702596</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.528200</td>
#       <td>0.691429</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.528900</td>
#       <td>0.698701</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.522600</td>
#       <td>0.703859</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-25
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-25/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-50
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-50/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-50/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-25] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-75
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-75/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-75/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-100
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-100/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-125
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-125/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-125/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-75] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-150
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-150/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-150/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-125] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-175
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-175/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-175/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-200/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-175] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-225
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-225/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-225/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-250
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-250/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-250/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-225] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-275
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-275/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-275/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-300
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-275] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-325
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-325/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-325/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_4/checkpoint-350
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_4/checkpoint-350/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_4/checkpoint-350/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_4/checkpoint-325] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../model/5fold_mmbt/fold_4/checkpoint-150 (score: 0.648417055606842).
# ***** Running Prediction *****
#   Num examples = 4993
#   Batch size = 12
# ***** Running Prediction *****
#   Num examples = 6000
#   Batch size = 12
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading configuration file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/573af37b6c39d672f2df687c06ad7d556476cbe43e5bf7771097187c45a3e7bf.abeb707b5d79387dd462e8bfb724637d856e98434b6931c769b8716c6f287258
# Model config BertConfig {
#   "_name_or_path": "cl-tohoku/bert-base-japanese-whole-word-masking",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "bert",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 0,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertJapaneseTokenizer",
#   "transformers_version": "4.21.1",
#   "type_vocab_size": 2,
#   "use_cache": true,
#   "vocab_size": 32000
# }
#
# loading weights file https://huggingface.co/cl-tohoku/bert-base-japanese-whole-word-masking/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/cabd9bbd81093f4c494a02e34eb57e405b7564db216404108c8e8caf10ede4fa.464b54997e35e3cc3223ba6d7f0abdaeb7be5b7648f275f57d839ee0f95611fb
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertModel: ['cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of BertModel were initialized from the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BertModel for predictions without further training.
# PyTorch: setting up devices
# Using cuda_amp half precision backend
# /opt/conda/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 19969
#   Num Epochs = 3
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 160
#   Gradient Accumulation steps = 20
#   Total optimization steps = 372
#     <div>
#
#       <progress value='372' max='372' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [372/372 31:45, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>0.686100</td>
#       <td>0.675377</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.673800</td>
#       <td>0.678738</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.662600</td>
#       <td>0.670941</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.661300</td>
#       <td>0.673730</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.669800</td>
#       <td>0.656670</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.642800</td>
#       <td>0.665400</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.628600</td>
#       <td>0.665497</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.617500</td>
#       <td>0.667931</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.625200</td>
#       <td>0.652825</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.641100</td>
#       <td>0.656348</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.572800</td>
#       <td>0.705030</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.545200</td>
#       <td>0.690961</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.533100</td>
#       <td>0.710390</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.547500</td>
#       <td>0.690516</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-25
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-25/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-25/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-50
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-50/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-50/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-75
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-75/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-75/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-25] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-50] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-100
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-100/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-100/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-125
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-125/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-125/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-75] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-150
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-150/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-150/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-175
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-175/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-175/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-150] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-200
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-200/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-200/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-175] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-225
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-225/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-225/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-125] due to args.save_total_limit
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-250
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-250/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-250/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-275
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-275/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-275/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-250] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-300
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-300/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-300/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-275] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-325
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-325/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-325/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-300] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 4993
#   Batch size = 12
# Saving model checkpoint to ../model/5fold_mmbt/fold_5/checkpoint-350
# Trainer.model is not a `PreTrainedModel`, only saving its state dict.
# tokenizer config file saved in ../model/5fold_mmbt/fold_5/checkpoint-350/tokenizer_config.json
# Special tokens file saved in ../model/5fold_mmbt/fold_5/checkpoint-350/special_tokens_map.json
# Deleting older checkpoint [../model/5fold_mmbt/fold_5/checkpoint-325] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ../model/5fold_mmbt/fold_5/checkpoint-225 (score: 0.652825117111206).
# ***** Running Prediction *****
#   Num examples = 4993
#   Batch size = 12
# ***** Running Prediction *****
#   Num examples = 6000
#   Batch size = 12

# %%
json_path_list = list(glob('../results/5fold_mmbt/*.json'))
acc_list = []
log_loss_list = []
for json_path in json_path_list:
    with open(json_path, 'r') as f:
        data = json.load(f)
    acc_list.append(data['acc'])
    log_loss_list.append(data['log_loss'])
print(f'acc mean: {np.mean(acc_list):.4f}, std: {np.std(acc_list):.4f}')
print(f'log loss mean: {np.mean(log_loss_list):.4f}, std: {np.std(log_loss_list):.4f}')
# Out:
# acc mean: 0.6262, std: 0.0103
# log loss mean: 0.6480, std: 0.0045

# %%
csv_path_list = list(glob('../results/5fold_mmbt/fold_*_submission.csv'))
is_laugh_arr = np.stack([pd.read_csv(csv_path)['is_laugh'] for csv_path in csv_path_list])
is_laugh_mean = np.mean(is_laugh_arr, axis=0)
submission_df['is_laugh'] = is_laugh_mean
output = str(RESULT_DIR / f'5fold_mean_submission.csv')
submission_df.to_csv(output, index=False)
